# %%
from helpers.data_prep import*
from helpers.eda import*
import pandas as pd 
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("spotify.csv")
df.head()
# Out:
#                  track_id                                         track_name      track_artist  track_popularity          track_album_id  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
df.shape
# Out:
# (32833, 23)

# %%
df.describe().T
# Out:
#                      count       mean       std      min        25%        50%        75%        max
# track_popularity 32833.000     42.477    24.984    0.000     24.000     45.000     62.000    100.000
# danceability     32833.000      0.655     0.145    0.000      0.563      0.672      0.761      0.983
# energy           32833.000      0.699     0.181    0.000      0.581      0.721      0.840      1.000
# key              32833.000      5.374     3.612    0.000      2.000      6.000      9.000     11.000
# loudness         32833.000     -6.719     2.988  -46.448     -8.171     -6.166     -4.645      1.275
# mode             32833.000      0.566     0.496    0.000      0.000      1.000      1.000      1.000
# speechiness      32833.000      0.107     0.101    0.000      0.041      0.062      0.132      0.918
# acousticness     32833.000      0.175     0.220    0.000      0.015      0.080      0.255      0.994
# ...

# %%
df.isnull()
# Out:
#        track_id  track_name  track_artist  track_popularity  track_album_id  track_album_name  track_album_release_date  playlist_name  playlist_id  playlist_genre  \
# 0         False       False         False             False           False             False                     False          False        False           False
# 1         False       False         False             False           False             False                     False          False        False           False
# 2         False       False         False             False           False             False                     False          False        False           False
# 3         False       False         False             False           False             False                     False          False        False           False
# 4         False       False         False             False           False             False                     False          False        False           False
# ...

# %%
df.isnull().sum()
# Out:
# track_id            0
# track_name          5
# track_artist        5
# track_popularity    0
# track_album_id      0
#                    ..
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# Length: 23, dtype: int64

# %%
upper_col_name(df)
# Out:
#                      TRACK_ID                                         TRACK_NAME      TRACK_ARTIST  TRACK_POPULARITY          TRACK_ALBUM_ID  \
# 0      6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1      0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3      75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4      1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# ...

# %%
check_df(df, head=5)
# Out:
# ##################### Shape #####################
# (32833, 23)
# ##################### Types #####################
# TRACK_ID             object
# TRACK_NAME           object
# TRACK_ARTIST         object
# TRACK_POPULARITY      int64
# TRACK_ALBUM_ID       object
#                      ...
# INSTRUMENTALNESS    float64
# LIVENESS            float64
# VALENCE             float64
# TEMPO               float64
# DURATION_MS           int64
# Length: 23, dtype: object
# ##################### Head #####################
#                  TRACK_ID                                         TRACK_NAME      TRACK_ARTIST  TRACK_POPULARITY          TRACK_ALBUM_ID  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# ...

# %%
grab_col_names(df, cat_th=10, car_th=20)
# Out:
# Observations: 32833
# Variables: 23
# cat_cols: 2
# num_cols: 12
# cat_but_car: 9
# num_but_cat: 1
# (['PLAYLIST_GENRE', 'MODE'],
#  ['TRACK_POPULARITY',
#   'DANCEABILITY',
#   'ENERGY',
#   'KEY',
#   'LOUDNESS',
#   'SPEECHINESS',
#   'ACOUSTICNESS',
#   'INSTRUMENTALNESS',
#   'LIVENESS',
#   'VALENCE',
#   'TEMPO',
#   'DURATION_MS'],
#  ['TRACK_ID',
#   'TRACK_NAME',
#   'TRACK_ARTIST',
#   'TRACK_ALBUM_ID',
#   'TRACK_ALBUM_NAME',
#   'TRACK_ALBUM_RELEASE_DATE',
#   'PLAYLIST_NAME',
#   'PLAYLIST_ID',
#   'PLAYLIST_SUBGENRE'])

# %%
def cat_summary(dataframe, col_name, plot=False):
    print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                        "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)}))
    print("##########################################")
    if plot:
        sns.countplot(x=dataframe[col_name], data=dataframe)
        plt.show()

# %%
cat_summary(df,"TRACK_ID",plot=False)
# Out:
#                         TRACK_ID  Ratio
# 7BKLCZ1jbUBVqRi2FVlTVw        10  0.030
# 14sOS5L36385FJ3OL8hew4         9  0.027
# 3eekarcy7kvN4yt5ZFzltW         9  0.027
# 2Fxmhks0bxGSBdJ92vM42m         8  0.024
# 2tnVG71enUj33Ic2nFN6kZ         8  0.024
# ...                          ...    ...
# 3AKwyujeGxTQSZNbx9Ka3c         1  0.003
# 3ITvHA9zhZZdBJsOsAUegF         1  0.003
# 5gsW8TMmNVnevjq13h0Nlp         1  0.003
# 4pN4icvWINm9uN3bElfbec         1  0.003
# 29zWqhca3zt5NsckZqDf6c         1  0.003
#
# [28356 rows x 2 columns]
# ##########################################

# %%
num_summary(df,"PLAYLIST_ID", plot=False)
# Out:
# count                      32833
# unique                       471
# top       4JkkvMpVl4lSioqQjeAL0q
# freq                         247
# Name: PLAYLIST_ID, dtype: object

# %%
target_summary_with_cat(df,"KEY","PLAYLIST_ID")
# Out:
#                         TARGET_MEAN
# PLAYLIST_ID
# 0275i1VNfBnsNbPl0QIBpG        5.289
# 03qQtbNHoJuFezRu2CnLuF        4.786
# 03sDEv7FN58Mb9CJOs1Tgn        6.227
# 06zrBJ5cts5aemZmqe80J7        5.957
# 07SNJ4MwYba9wwmzrbjmYi        5.887
# ...                             ...
# 7sq6nuruoMyDhEWkX2oYOg        5.370
# 7tkgK1tm9hYkWp7EFyOcAr        6.014
# 7vJOXFe40axY7qS39vGDyH        4.933
# 7xWdFCrU5Gka6qp1ODrSdK        5.000
# 7xWuNevFBmwnFEg6wzdCc7        6.143
#
# [471 rows x 1 columns]

# %%
target_summary_with_num(df,"TRACK_ALBUM_NAME","TRACK_POPULARITY")
# Out:
#                                                     TRACK_POPULARITY
# TRACK_ALBUM_NAME
# !                                                             66.000
# "Awaken, My Love!"                                            18.273
# "Crazy Bitch"                                                  0.000
# "Forever King"                                                34.000
# "Heroes" (2017 Remastered Version)                            75.000
# ...                                                              ...
# 浮遊空間                                                          32.500
# 真っ赤な太陽                                                        29.000
# 都市女子                                                          17.000
# 화양연화 The Most Beautiful Moment In Life, Pt. 1                  0.000
# 화양연화 The Most Beautiful Moment In Life: Young F...             0.000
#
# [19743 rows x 1 columns]

# %%
high_correlated_cols(df,plot=False, corr_th=0.90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 high_correlated_cols(df,plot=False, corr_th=0.90)
#
# File ~\deneme\ML\helpers\eda.py:139, in high_correlated_cols(dataframe, plot, corr_th)
#     138 def high_correlated_cols(dataframe, plot=False, corr_th=0.90):
# --> 139     corr = dataframe[num_cols].corr()
#     140     cor_matrix = corr.abs()
#     141     upper_triangle_matrix = cor_matrix.where(np.triu(np.ones(cor_matrix.shape), k=1).astype(np.bool))
#
# NameError: name 'num_cols' is not defined

# %%
def visualization(dataframe,columns):
    dataframe[columns].hist(grid=True,figsize=(10,6))

# %%
visualization(df,"TRACK_POPULARITY")

# %%
visualization(df,"TEMPO")

# %%
def pie_visualization(df,column):
    df[column].value_counts().plot.pie(legend=True,autopct="%1.1f%%")

# %%
pie_visualization(df,"PLAYLIST_GENRE")

# %%
def graph(x,y,df):
    sbn.boxplot(x=x , y=y, data=df)

    plt.figure(figsize=(10,10))
    
    plt.show()

# %%
graph("KEY","ENERGY",df)

# %%
def plotHistogram(degisken):
    """
        Girdi: Değisken / sütun ismi
        Çıktı: İlgili değişkenin histogramı
    """
    plt.figure()
    plt.hist(df[degisken], bins=85, color = "blue")
    plt.xlabel(degisken)
    plt.ylabel("Frekans")
    plt.title("Veri Sıklığı - {}".format(degisken))
    plt.show()

# %%
plotHistogram("KEY")

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sbn.countplot("KEY",hue="size",data=df)

plt.subplot(1,2,2)
sbn.countplot("TRACK_POPULARITY",hue="size",data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [127], in <cell line: 3>()
#       1 plt.figure(figsize=(10,10))
#       2 plt.subplot(1,2,1)
# ----> 3 sbn.countplot("KEY",hue="size",data=df)
#       5 plt.subplot(1,2,2)
#       6 sbn.countplot("TRACK_POPULARITY",hue="size",data=df)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
outlier_thresholds(df,"KEY", q1=0.05, q3=0.95)
# Out:
# (-16.5, 27.5)

# %%
check_outlier(df, "KEY")
# Out:
# False

# %%
check_outlier(df, 'MODE')
# Out:
# False

# %%
grab_outliers(df,'TRACK_POPULARITY', index=False)
# Out:
# Empty DataFrame
# Columns: [TRACK_ID, TRACK_NAME, TRACK_ARTIST, TRACK_POPULARITY, TRACK_ALBUM_ID, TRACK_ALBUM_NAME, TRACK_ALBUM_RELEASE_DATE, PLAYLIST_NAME, PLAYLIST_ID, PLAYLIST_GENRE, PLAYLIST_SUBGENRE, DANCEABILITY, ENERGY, KEY, LOUDNESS, MODE, SPEECHINESS, ACOUSTICNESS, INSTRUMENTALNESS, LIVENESS, VALENCE, TEMPO, DURATION_MS]
# Index: []

# %%
remove_outlier (dataframe, , q1=0.05, q3=0.95)
